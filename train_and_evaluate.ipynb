# %% [markdown]
# <a href="https://colab.research.google.com/github/bhartiansh/cnn_pruning_cifar100/blob/main/train_and_evaluate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/bhartiansh/cnn_pruning_cifar100.git
# %cd cnn_pruning_cifar100
# Out:
# Cloning into 'cnn_pruning_cifar100'...
# remote: Enumerating objects: 16, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 16 (delta 1), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (16/16), 5.09 KiB | 5.09 MiB/s, done.
# Resolving deltas: 100% (1/1), done.
# /content/cnn_pruning_cifar100

# %%
# train_and_evaluate.py

from data_preprocessing import load_cifar100_data
from mobilenetv2_baseline import build_mobilenetv2_baseline
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import os, json

train_gen, val_gen = load_cifar100_data()

model = build_mobilenetv2_baseline()

if not os.path.exists("models"):
    os.makedirs("models")

callbacks = [
    EarlyStopping(patience=5, restore_best_weights=True),
    ModelCheckpoint("models/mobilenetv2_baseline.keras", save_best_only=True)
]

history = model.fit(train_gen, validation_data=val_gen, epochs=30, callbacks=callbacks)

# Save metrics
if not os.path.exists("results"):
    os.makedirs("results")

with open("results/baseline_metrics.json", "w") as f:
    json.dump(history.history, f)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169001437/169001437 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# /content/cnn_pruning_cifar100/mobilenetv2_baseline.py:9: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_model = MobileNetV2(weights="imagenet", include_top=False, input_shape=(32, 32, 3))
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/30
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 101s 73ms/step - accuracy: 0.0481 - loss: 4.7412 - val_accuracy: 0.0343 - val_loss: 4.6638
# Epoch 2/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 45ms/step - accuracy: 0.1803 - loss: 3.5412 - val_accuracy: 0.1101 - val_loss: 4.0053
# Epoch 3/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 45ms/step - accuracy: 0.2569 - loss: 3.0517 - val_accuracy: 0.2301 - val_loss: 3.2604
# Epoch 4/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 45ms/step - accuracy: 0.3064 - loss: 2.7397 - val_accuracy: 0.3073 - val_loss: 2.7724
# Epoch 5/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 45ms/step - accuracy: 0.3525 - loss: 2.5194 - val_accuracy: 0.3627 - val_loss: 2.4685
# Epoch 6/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 46ms/step - accuracy: 0.3903 - loss: 2.3443 - val_accuracy: 0.3998 - val_loss: 2.3089
# Epoch 7/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 45ms/step - accuracy: 0.4187 - loss: 2.1886 - val_accuracy: 0.4301 - val_loss: 2.1539
# Epoch 8/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 45ms/step - accuracy: 0.4420 - loss: 2.0636 - val_accuracy: 0.4482 - val_loss: 2.1149
# Epoch 9/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 46ms/step - accuracy: 0.4680 - loss: 1.9628 - val_accuracy: 0.4692 - val_loss: 2.0030
# Epoch 10/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 45ms/step - accuracy: 0.4895 - loss: 1.8705 - val_accuracy: 0.4656 - val_loss: 2.0425
# Epoch 11/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 46ms/step - accuracy: 0.5129 - loss: 1.7513 - val_accuracy: 0.4880 - val_loss: 1.9292
# Epoch 12/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 42s 46ms/step - accuracy: 0.5272 - loss: 1.6928 - val_accuracy: 0.4978 - val_loss: 1.9179
# Epoch 13/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 45ms/step - accuracy: 0.5437 - loss: 1.6154 - val_accuracy: 0.5116 - val_loss: 1.8645
# Epoch 14/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 43ms/step - accuracy: 0.5601 - loss: 1.5610 - val_accuracy: 0.5027 - val_loss: 1.9034
# Epoch 15/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 45ms/step - accuracy: 0.5732 - loss: 1.4920 - val_accuracy: 0.5224 - val_loss: 1.8369
# Epoch 16/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 45ms/step - accuracy: 0.5903 - loss: 1.4219 - val_accuracy: 0.5301 - val_loss: 1.7888
# Epoch 17/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 44ms/step - accuracy: 0.6030 - loss: 1.3723 - val_accuracy: 0.5298 - val_loss: 1.8071
# Epoch 18/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 44ms/step - accuracy: 0.6134 - loss: 1.3325 - val_accuracy: 0.5347 - val_loss: 1.7968
# Epoch 19/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 44ms/step - accuracy: 0.6291 - loss: 1.2689 - val_accuracy: 0.5298 - val_loss: 1.8352
# Epoch 20/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 45ms/step - accuracy: 0.6377 - loss: 1.2369 - val_accuracy: 0.5364 - val_loss: 1.7944
# Epoch 21/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 44ms/step - accuracy: 0.6507 - loss: 1.1876 - val_accuracy: 0.5409 - val_loss: 1.7819
# Epoch 22/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 43ms/step - accuracy: 0.6588 - loss: 1.1543 - val_accuracy: 0.5441 - val_loss: 1.8040
# Epoch 23/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 44ms/step - accuracy: 0.6707 - loss: 1.1043 - val_accuracy: 0.5450 - val_loss: 1.7989
# Epoch 24/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 43ms/step - accuracy: 0.6772 - loss: 1.0853 - val_accuracy: 0.5523 - val_loss: 1.7504
# Epoch 25/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 44ms/step - accuracy: 0.6931 - loss: 1.0267 - val_accuracy: 0.5562 - val_loss: 1.7521
# Epoch 26/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 44ms/step - accuracy: 0.6969 - loss: 1.0050 - val_accuracy: 0.5536 - val_loss: 1.7630
# Epoch 27/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 45ms/step - accuracy: 0.7075 - loss: 0.9761 - val_accuracy: 0.5623 - val_loss: 1.7406
# Epoch 28/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 44ms/step - accuracy: 0.7152 - loss: 0.9429 - val_accuracy: 0.5606 - val_loss: 1.7420
# Epoch 29/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 33s 42ms/step - accuracy: 0.7172 - loss: 0.9223 - val_accuracy: 0.5609 - val_loss: 1.7602
# Epoch 30/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 44ms/step - accuracy: 0.7342 - loss: 0.8778 - val_accuracy: 0.5508 - val_loss: 1.8275
